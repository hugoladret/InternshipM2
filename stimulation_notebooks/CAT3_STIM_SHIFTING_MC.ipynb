# %% [markdown]
# # Stimulations with fixed shifts to produce a nice clocklike changes
# We change by theta and each one by b_theta

# %%
import os
import numpy as np
import MotionClouds as mc
import datetime
import matplotlib.pyplot as plt
import csv
from tqdm import tqdm
import imageio
import warnings
from psychopy import visual, core, event
import MotionClouds as MC
import itertools

downscale = 1
fx, fy, ft = mc.get_grids(mc.N_X//downscale, mc.N_Y//downscale, mc.N_frame//downscale)

now = datetime.datetime.now()
strtime = now.strftime("%Y-%m-%d_%H:%M:%S")   

mc.figpath = os.path.join('sequences/CATMCSHIFTS_psychopy_%s'% strtime)
if not(os.path.isdir(mc.figpath)): os.mkdir(mc.figpath)
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Orientations
N_thetas = 12
thetas = np.linspace(0,np.pi, N_thetas) # we offset by pi/2 to prevent problems with matplotlib's displays and psychopy

# Noise
B_thetas = np.linspace(np.pi/2, np.pi/32, 8)/2.5

# Presentation of each pattern
stim_duration = 2 #s

# Repetition of each block
repetition = 5

rng = np.random.RandomState(42)
sequence = list(itertools.product(thetas, B_thetas))

plt.scatter(*zip(*sequence))

# %%
sorted_by_btheta = sorted(sequence, key=lambda tup: tup[1])
sorted_by_btheta
sequence = sorted_by_btheta

# %%
print('This protocolsetup lasts for approx. [%s] minutes (not counting blanks and inter-block screens)' % (N_thetas*len(B_thetas)*stim_duration*repetition/60))
print('Each of the [%s] block lasts for [%s]s' % (repetition, stim_duration*len(sequence)))
print('using [%s] thetas and [%s] b_thetas' % (N_thetas, len(B_thetas)))
print('and presenting each pattern for [%s]s' % stim_duration)
# Out:
# This protocolsetup lasts for approx. [16.0] minutes (not counting blanks and inter-block screens)
# Each of the [5] block lasts for [192]s
# using [12] thetas and [8] b_thetas
# and presenting each pattern for [2]s

# %%
import imageio.core.util

def silence_imageio_warning(*args, **kwargs):
    pass

imageio.core.util._precision_warn = silence_imageio_warning

def get_keypress():
    keys = event.getKeys()
    if keys:
        return keys[0]
    else:
        return None

def generate_cloud(theta, b_theta, itr,
                   N_X, N_Y, seed, contrast=1.,
                  transition = False, save = True):
    
    fx, fy, ft = mc.get_grids(N_X, N_Y, 1)
    disk = mc.frequency_radius(fx, fy, ft) < .5

    mc_i = mc.envelope_gabor(fx, fy, ft,
                             V_X=0., V_Y=0., B_V=0.,
                             sf_0=sf_0, B_sf=B_sf,
                             theta=theta, B_theta=b_theta)

    im_ = np.zeros((N_X, N_Y,1))
    im_ += mc.rectif(mc.random_cloud(mc_i, seed=seed),
                     contrast=contrast)
    im_ *= disk  # masking outside the disk
    im_ += -.5
    im_ += .5*(1-disk)  # gray outside the disk

    if transition : im_[472:500, 12:40] = 1
    else : im_[472:500, 12:40] = -.25

    # data appending
    if save :
        with open(mc.figpath+'/sequence.csv', "a+") as writer_file:
            data_writer = csv.writer(
                writer_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
            data_writer.writerow([itr, theta, b_theta, sf_0, B_sf, N_X, N_Y])
            
        imageio.imwrite(mc.figpath+'/%s.png' % itr, im_[:,:,0])

    return im_

width = 29.7*256/1050
N_X, N_Y = 512, 512
sf_0 = 4*width/N_X/2
sf_0 = .03
B_sf = sf_0
im = generate_cloud(sequence[0][0], sequence[0][1], 1, N_X, N_Y, 42, transition = True, save = True)

plt.figure(figsize = (12,6))
plt.imshow(im[:,:,0])

# %%
now = datetime.datetime.now()
strtime = now.strftime("%Y-%m-%d_%H:%M:%S")   

mc.figpath = os.path.join('sequences/CATMCshifts_psychopy_%s'% strtime)
if not(os.path.isdir(mc.figpath)): os.mkdir(mc.figpath)
    
# Initializing PsychoPy window
win = visual.Window(fullscr=True, color=[0.0075,0.0075,0.0075], winType='pygame', monitor='testMonitor', units='height')
mouse = event.Mouse(visible=False)

MC_temp = generate_cloud(theta = np.pi/2, b_theta=np.pi/2, contrast = 1, 
                        N_X = N_X, N_Y = N_Y, seed = 42, transition = False, itr = 0, save = False)
bitmap1 = visual.ImageStim(win, MC_temp, size=1, units='height', flipVert = True)
bitmap1.autolog = False
bitmap2 = visual.ImageStim(win, MC_temp, size=1, units='height', flipVert = True)
bitmap2.autolog = False

bitmap3 = visual.ImageStim(win, MC_temp, size=1, units='height')
bitmap3.autolog = False
bitmap3.setImage(np.full((512,512), -1))


for stimulations in range(len(sequence)*repetition):
    trial = stimulations%len(sequence) # converting total stimulations in intra-block trial
    
    #Waiting 5s at the beginning of a new block
    if stimulations == 0 :
        clock0 = core.Clock()
        print('Beginning new block, drawing blackscreen.')
        while clock0.getTime() < stim_duration*3 :
            bitmap3.draw()
            win.flip()
        
            
    clock = core.Clock()
    print('Trial no.', trial)
    
    #stim
    MC1 = generate_cloud(theta = sequence[trial][0], b_theta=sequence[trial][1], contrast = 1, 
                        N_X = N_X, N_Y = N_Y, seed = 42, transition = False, itr = stimulations, save = True)[:,:,0]
    bitmap1.setImage(MC1)
    
    #stim with square for 6 frames before jump
    MC2 = generate_cloud(theta = sequence[trial][0], b_theta=sequence[trial][1], contrast = 1, 
                        N_X = N_X, N_Y = N_Y, seed = 42, transition = True, itr = stimulations, save = False)[:,:,0]
    bitmap2.setImage(MC2)
    
    #early terminator
    key = get_keypress()
    if key == 'escape' : 
        win.close()
        core.quit()
        
    #timing one presentation, it works perfectly fine
    while clock.getTime() < stim_duration + .1:
        if 0.0 <= clock.getTime() < stim_duration:  # fixation
            bitmap1.draw()
        if stim_duration <= clock.getTime() < stim_duration + .1:
            bitmap2.draw()
        win.flip()       

win.close()
# Out:
# Beginning new block, drawing blackscreen.
# Trial no. 0
# Trial no. 1
# Trial no. 2
# Trial no. 3
# Trial no. 4
# Trial no. 5
# Trial no. 6
# Trial no. 7
# Trial no. 8
# Trial no. 9
# Trial no. 10
# Trial no. 11
# Trial no. 12
# Trial no. 13
# Trial no. 14
# Trial no. 15
# Trial no. 16
# Trial no. 17
# Trial no. 18
# Trial no. 19
# Trial no. 20
# Trial no. 21
# Trial no. 22
# Trial no. 23
# Trial no. 24
# Trial no. 25
# Trial no. 26
# Trial no. 27
# Trial no. 28
# Trial no. 29
# Trial no. 30
# Trial no. 31
# Trial no. 32
# Trial no. 33
# Trial no. 34
# Trial no. 35
# Trial no. 36
# Trial no. 37
# Trial no. 38
# Trial no. 39
# Trial no. 40
# Trial no. 41
# Trial no. 42
# Trial no. 43
# Trial no. 44
# Trial no. 45
# Trial no. 46
# Trial no. 47
# Trial no. 48
# Trial no. 49
# Trial no. 50
# Trial no. 51
# Trial no. 52
# Trial no. 53
# Trial no. 54
# Trial no. 55
# Trial no. 56
# Trial no. 57
# Trial no. 58
# Trial no. 59
# Trial no. 60
# Trial no. 61
# Trial no. 62
# Trial no. 63
# Trial no. 64
# Trial no. 65
# Trial no. 66
# Trial no. 67
# Trial no. 68
# Trial no. 69
# Trial no. 70
# Trial no. 71
# Trial no. 72
# Trial no. 73
# Trial no. 74
# Trial no. 75
# Trial no. 76
# Trial no. 77
# Trial no. 78
# Trial no. 79
# Trial no. 80
# Trial no. 81
# Trial no. 82
# Trial no. 83
# Trial no. 84
# Trial no. 85
# Trial no. 86
# Trial no. 87
# Trial no. 88
# Trial no. 89
# Trial no. 90
# Trial no. 91
# Trial no. 92
# Trial no. 93
# Trial no. 94
# Trial no. 95
# Trial no. 0
# Trial no. 1
# Trial no. 2
# Trial no. 3
# Trial no. 4
# Trial no. 5
# Trial no. 6
# Trial no. 7
# Trial no. 8
# Trial no. 9
# Trial no. 10
# Trial no. 11
# Trial no. 12
# Trial no. 13
# Trial no. 14
# Trial no. 15
# Trial no. 16
# Trial no. 17
# Trial no. 18
# Trial no. 19
# Trial no. 20
# Trial no. 21
# Trial no. 22
# Trial no. 23
# Trial no. 24
# Trial no. 25
# Trial no. 26
# Trial no. 27
# Trial no. 28
# Trial no. 29
# Trial no. 30
# Trial no. 31
# Trial no. 32
# Trial no. 33
# Trial no. 34
# Trial no. 35
# Trial no. 36
# Trial no. 37
# Trial no. 38
# Trial no. 39
# Trial no. 40
# Trial no. 41
# Trial no. 42
# Trial no. 43
# Trial no. 44
# Trial no. 45
# Trial no. 46
# Trial no. 47
# Trial no. 48
# Trial no. 49
# Trial no. 50
# Trial no. 51
# Trial no. 52
# Trial no. 53
# Trial no. 54
# Trial no. 55
# Trial no. 56
# Trial no. 57
# Trial no. 58
# Trial no. 59
# Trial no. 60
# Trial no. 61
# Trial no. 62
# Trial no. 63
# Trial no. 64
# Trial no. 65
# Trial no. 66
# Trial no. 67
# Trial no. 68
# Trial no. 69
# Trial no. 70
# Trial no. 71
# Trial no. 72
# Trial no. 73
# Trial no. 74
# Trial no. 75
# Trial no. 76
# Trial no. 77
# Trial no. 78
# Trial no. 79
# Trial no. 80
# Trial no. 81
# Trial no. 82
# Trial no. 83
# Trial no. 84
# Trial no. 85
# Trial no. 86
# Trial no. 87
# Trial no. 88
# Trial no. 89
# Trial no. 90
# Trial no. 91
# Trial no. 92
# Trial no. 93
# Trial no. 94
# Trial no. 95
# Trial no. 0
# Trial no. 1
# Trial no. 2
# Trial no. 3
# Trial no. 4
# Trial no. 5
# Trial no. 6
# Trial no. 7
# Trial no. 8
# Trial no. 9
# Trial no. 10
# Trial no. 11
# Trial no. 12
# Trial no. 13
# Trial no. 14
# Trial no. 15
# Trial no. 16
# Trial no. 17
# Trial no. 18
# Trial no. 19
# Trial no. 20
# Trial no. 21
# Trial no. 22
# Trial no. 23
# Trial no. 24
# Trial no. 25
# Trial no. 26
# Trial no. 27
# Trial no. 28
# Trial no. 29
# Trial no. 30
# Trial no. 31
# Trial no. 32
# Trial no. 33
# Trial no. 34
# Trial no. 35
# Trial no. 36
# Trial no. 37
# Trial no. 38
# Trial no. 39
# Trial no. 40
# Trial no. 41
# Trial no. 42
# Trial no. 43
# Trial no. 44
# Trial no. 45
# Trial no. 46
# Trial no. 47
# Trial no. 48
# Trial no. 49
# Trial no. 50
# Trial no. 51
# Trial no. 52
# Trial no. 53
# Trial no. 54
# Trial no. 55
# Trial no. 56
# Trial no. 57
# Trial no. 58
# Trial no. 59
# Trial no. 60
# Trial no. 61
# Trial no. 62
# Trial no. 63
# Trial no. 64
# Trial no. 65
# Trial no. 66
# Trial no. 67
# Trial no. 68
# Trial no. 69
# Trial no. 70
# Trial no. 71
# Trial no. 72
# Trial no. 73
# Trial no. 74
# Trial no. 75
# Trial no. 76
# Trial no. 77
# Trial no. 78
# Trial no. 79
# Trial no. 80
# Trial no. 81
# Trial no. 82
# Trial no. 83
# Trial no. 84
# Trial no. 85
# Trial no. 86
# Trial no. 87
# Trial no. 88
# Trial no. 89
# Trial no. 90
# Trial no. 91
# Trial no. 92
# Trial no. 93
# Trial no. 94
# Trial no. 95
# Trial no. 0
# Trial no. 1
# Trial no. 2
# Trial no. 3
# Trial no. 4
# Trial no. 5
# Trial no. 6
# Trial no. 7
# Trial no. 8
# Trial no. 9
# Trial no. 10
# Trial no. 11
# Trial no. 12
# Trial no. 13
# Trial no. 14
# Trial no. 15
# Trial no. 16
# Trial no. 17
# Trial no. 18
# Trial no. 19
# Trial no. 20
# Trial no. 21
# Trial no. 22
# Trial no. 23
# Trial no. 24
# Trial no. 25
# Trial no. 26
# Trial no. 27
# Trial no. 28
# Trial no. 29
# Trial no. 30
# Trial no. 31
# Trial no. 32
# Trial no. 33
# Trial no. 34
# Trial no. 35
# Trial no. 36
# Trial no. 37
# Trial no. 38
# Trial no. 39
# Trial no. 40
# Trial no. 41
# Trial no. 42
# Trial no. 43
# Trial no. 44
# Trial no. 45
# Trial no. 46
# Trial no. 47
# Trial no. 48
# Trial no. 49
# Trial no. 50
# Trial no. 51
# Trial no. 52
# Trial no. 53
# Trial no. 54
# Trial no. 55
# Trial no. 56
# Trial no. 57
# Trial no. 58
# Trial no. 59
# Trial no. 60
# Trial no. 61
# Trial no. 62
# Trial no. 63
# Trial no. 64
# Trial no. 65
# Trial no. 66
# Trial no. 67
# Trial no. 68
# Trial no. 69
# Trial no. 70
# Trial no. 71
# Trial no. 72
# Trial no. 73
# Trial no. 74
# Trial no. 75
# Trial no. 76
# Trial no. 77
# Trial no. 78
# Trial no. 79
# Trial no. 80
# Trial no. 81
# Trial no. 82
# Trial no. 83
# Trial no. 84
# Trial no. 85
# Trial no. 86
# Trial no. 87
# Trial no. 88
# Trial no. 89
# Trial no. 90
# Trial no. 91
# Trial no. 92
# Trial no. 93
# Trial no. 94
# Trial no. 95
# Trial no. 0
# Trial no. 1
# Trial no. 2
# Trial no. 3
# Trial no. 4
# Trial no. 5
# Trial no. 6
# Trial no. 7
# Trial no. 8
# Trial no. 9
# Trial no. 10
# Trial no. 11
# Trial no. 12
# Trial no. 13
# Trial no. 14
# Trial no. 15
# Trial no. 16
# Trial no. 17
# Trial no. 18
# Trial no. 19
# Trial no. 20
# Trial no. 21
# Trial no. 22
# Trial no. 23
# Trial no. 24
# Trial no. 25
# Trial no. 26
# Trial no. 27
# Trial no. 28
# Trial no. 29
# Trial no. 30
# Trial no. 31
# Trial no. 32
# Trial no. 33
# Trial no. 34
# Trial no. 35
# Trial no. 36
# Trial no. 37
# Trial no. 38
# Trial no. 39
# Trial no. 40
# Trial no. 41
# Trial no. 42
# Trial no. 43
# Trial no. 44
# Trial no. 45
# Trial no. 46
# Trial no. 47
# Trial no. 48
# Trial no. 49
# Trial no. 50
# Trial no. 51
# Trial no. 52
# Trial no. 53
# Trial no. 54
# Trial no. 55
# Trial no. 56
# Trial no. 57
# Trial no. 58
# Trial no. 59
# Trial no. 60
# Trial no. 61
# Trial no. 62
# Trial no. 63
# Trial no. 64
# Trial no. 65
# Trial no. 66
# Trial no. 67
# Trial no. 68
# Trial no. 69
# Trial no. 70
# Trial no. 71
# Trial no. 72
# Trial no. 73
# Trial no. 74
# Trial no. 75
# Trial no. 76
# Trial no. 77
# Trial no. 78
# Trial no. 79
# Trial no. 80
# Trial no. 81
# Trial no. 82
# Trial no. 83
# Trial no. 84
# Trial no. 85
# Trial no. 86
# Trial no. 87
# Trial no. 88
# Trial no. 89
# Trial no. 90
# Trial no. 91
# Trial no. 92
# Trial no. 93
# Trial no. 94
# Trial no. 95
# 2.1128 	WARNING 	User requested fullscreen with size [800 600], but screen is actually [1920, 1080]. Using actual size
